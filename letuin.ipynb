# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc("font", family = "Malgun Gothic")

# 글씨가 뭉게져서 보이는 것 같으면 아래의 설정을 통해서 개선할 수 있음
from IPython.display import display
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
# 여기는 건드리지 말 것!

df = pd.read_excel('score.xlsx', index_col=None, header=[0,1])
df["언어오답률"] = df["언어", "못품"]/df["언어", "못품+틀림"]
df["수리오답률"] = df["수리","못품"]/df["수리", "못품+틀림"]
df["추리오답률"] = df["추리","못품"]/df["추리", "못품+틀림"]
df["시각오답률"] = df["시각","못품"]/df["시각", "못품+틀림"]
# df

df.style.set_properties(subset=[("언어", "못품+틀림"), ("수리", "못품+틀림"), ("추리", "못품+틀림"), ("시각", "못품+틀림")], 
                        **{'background-color':"lightgreen"})\
        .set_properties(subset=[("언어", "못품"), ("수리", "못품"), ("추리", "못품"), ("시각", "못품")], 
                       **{'background-color':"pink"})
# Out:
# <style  type="text/css" >
#     #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row0_col3 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row0_col4 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row0_col5 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row0_col6 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row0_col7 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row0_col8 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row0_col9 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row0_col10 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row1_col3 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row1_col4 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row1_col5 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row1_col6 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row1_col7 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row1_col8 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row1_col9 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row1_col10 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row2_col3 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row2_col4 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row2_col5 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row2_col6 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row2_col7 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row2_col8 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row2_col9 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row2_col10 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row3_col3 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row3_col4 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row3_col5 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row3_col6 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row3_col7 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row3_col8 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row3_col9 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row3_col10 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row4_col3 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row4_col4 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row4_col5 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row4_col6 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row4_col7 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row4_col8 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row4_col9 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row4_col10 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row5_col3 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row5_col4 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row5_col5 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row5_col6 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row5_col7 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row5_col8 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row5_col9 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row5_col10 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row6_col3 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row6_col4 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row6_col5 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row6_col6 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row6_col7 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row6_col8 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row6_col9 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row6_col10 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row7_col3 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row7_col4 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row7_col5 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row7_col6 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row7_col7 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row7_col8 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row7_col9 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row7_col10 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row8_col3 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row8_col4 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row8_col5 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row8_col6 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row8_col7 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row8_col8 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row8_col9 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row8_col10 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row9_col3 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row9_col4 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row9_col5 {
#             background-color:  pink;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row9_col6 {
#             background-color:  lightgreen;
#         }    #T_dd34d9f6_5d5e_11ea_ae67_b808cfcc3516row9_col7 {

# %% [markdown]
# ---

# %% [markdown]
# # <font color=red> Letuin </font>

# %%
df = pd.read_excel('score.xlsx', index_col=[0], header=[0,1])

letuin1 = df.loc[(df["Unnamed: 1_level_0", "교재"] == "렛유인") & (df["Unnamed: 2_level_0", "회차"] ==1)]
letuin1.style.background_gradient(cmap='summer_r')
# print(letuin1)
# print(letuin1)

letuin2 = df.loc[(df["Unnamed: 1_level_0", "교재"] == "렛유인") & (df["Unnamed: 2_level_0", "회차"] ==2)]
letuin2.style.background_gradient(cmap='summer_r')

letuin3 = df.loc[(df["Unnamed: 1_level_0", "교재"] == "렛유인") & (df["Unnamed: 2_level_0", "회차"] ==3)]
letuin3.style.background_gradient(cmap='summer_r')

display(letuin1.style.background_gradient(cmap='summer_r'))
display(letuin2.style.background_gradient(cmap='summer_r'))
display(letuin3.style.background_gradient(cmap='summer_r'))
# 각 과목당 오답률
# df.iloc[:,9:]
# Out:
# <style  type="text/css" >
#     #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row0_col2 {
#             background-color:  #66b266;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row0_col3 {
#             background-color:  #6db666;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row0_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row0_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row0_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row0_col7 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row0_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row0_col9 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row1_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row1_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row1_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row1_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row1_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row2_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row2_col2 {
#             background-color:  #339966;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row2_col3 {
#             background-color:  #5bad66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row2_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row2_col5 {
#             background-color:  #389c66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row2_col6 {
#             background-color:  #7fbf66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row2_col7 {
#             background-color:  #5dae66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row2_col8 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row2_col9 {
#             background-color:  #2a9466;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row3_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row3_col2 {
#             background-color:  #339966;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row3_col3 {
#             background-color:  #7fbf66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row3_col4 {
#             background-color:  #3f9f66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row3_col5 {
#             background-color:  #389c66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row3_col6 {
#             background-color:  #1f8f66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row3_col7 {
#             background-color:  #2e9666;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row3_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row3_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row4_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row4_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row4_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row4_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row4_col7 {
#             background-color:  #178b66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row4_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row4_col9 {
#             background-color:  #aad466;
#             color:  #000000;
#         }</style><table id="T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Unnamed: 1_level_0</th>        <th class="col_heading level0 col1" >Unnamed: 2_level_0</th>        <th class="col_heading level0 col2" colspan=2>언어</th>        <th class="col_heading level0 col4" colspan=2>수리</th>        <th class="col_heading level0 col6" colspan=2>추리</th>        <th class="col_heading level0 col8" colspan=2>시각</th>    </tr>    <tr>        <th class="index_name level1" >이름</th>        <th class="col_heading level1 col0" >교재</th>        <th class="col_heading level1 col1" >회차</th>        <th class="col_heading level1 col2" >못품</th>        <th class="col_heading level1 col3" >못품+틀림</th>        <th class="col_heading level1 col4" >못품</th>        <th class="col_heading level1 col5" >못품+틀림</th>        <th class="col_heading level1 col6" >못품</th>        <th class="col_heading level1 col7" >못품+틀림</th>        <th class="col_heading level1 col8" >못품</th>        <th class="col_heading level1 col9" >못품+틀림</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516level0_row0" class="row_heading level0 row0" >박서진</th>
#                         <td id="T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row0_col0" class="data row0 col0" >렛유인</td>
#                         <td id="T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row0_col2" class="data row0 col2" >3</td>
#                         <td id="T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row0_col3" class="data row0 col3" >8</td>
#                         <td id="T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row0_col4" class="data row0 col4" >4</td>
#                         <td id="T_dd54f7c0_5d5e_11ea_9b81_b808cfcc3516row0_col5" class="data row0 col5" >9</td>
#                         <td id="T_dd54f7c0_5d5e_11ea_9b
# <style  type="text/css" >
# </style><table id="T_dd578c78_5d5e_11ea_a001_b808cfcc3516" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Unnamed: 1_level_0</th>        <th class="col_heading level0 col1" >Unnamed: 2_level_0</th>        <th class="col_heading level0 col2" colspan=2>언어</th>        <th class="col_heading level0 col4" colspan=2>수리</th>        <th class="col_heading level0 col6" colspan=2>추리</th>        <th class="col_heading level0 col8" colspan=2>시각</th>    </tr>    <tr>        <th class="index_name level1" >이름</th>        <th class="col_heading level1 col0" >교재</th>        <th class="col_heading level1 col1" >회차</th>        <th class="col_heading level1 col2" >못품</th>        <th class="col_heading level1 col3" >못품+틀림</th>        <th class="col_heading level1 col4" >못품</th>        <th class="col_heading level1 col5" >못품+틀림</th>        <th class="col_heading level1 col6" >못품</th>        <th class="col_heading level1 col7" >못품+틀림</th>        <th class="col_heading level1 col8" >못품</th>        <th class="col_heading level1 col9" >못품+틀림</th>    </tr></thead><tbody>
#         </tbody></table>
# <style  type="text/css" >
# </style><table id="T_dd595fe4_5d5e_11ea_a864_b808cfcc3516" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Unnamed: 1_level_0</th>        <th class="col_heading level0 col1" >Unnamed: 2_level_0</th>        <th class="col_heading level0 col2" colspan=2>언어</th>        <th class="col_heading level0 col4" colspan=2>수리</th>        <th class="col_heading level0 col6" colspan=2>추리</th>        <th class="col_heading level0 col8" colspan=2>시각</th>    </tr>    <tr>        <th class="index_name level1" >이름</th>        <th class="col_heading level1 col0" >교재</th>        <th class="col_heading level1 col1" >회차</th>        <th class="col_heading level1 col2" >못품</th>        <th class="col_heading level1 col3" >못품+틀림</th>        <th class="col_heading level1 col4" >못품</th>        <th class="col_heading level1 col5" >못품+틀림</th>        <th class="col_heading level1 col6" >못품</th>        <th class="col_heading level1 col7" >못품+틀림</th>        <th class="col_heading level1 col8" >못품</th>        <th class="col_heading level1 col9" >못품+틀림</th>    </tr></thead><tbody>
#         </tbody></table>

# %%
letuin1_nonreplied = letuin1.iloc[:,[2,4,6,8]]
letuin1_total = letuin1.iloc[:,[3,5,7,9]]
letuin2_nonreplied = letuin2.iloc[:,[2,4,6,8]]
letuin2_total = letuin2.iloc[:,[3,5,7,9]]
letuin3_nonreplied = letuin3.iloc[:,[2,4,6,8]]
letuin3_total = letuin3.iloc[:,[3,5,7,9]]

# %% [markdown]
# ### 개인별  (못푼 개수) & (못푼+틀린 개수)

# %%
figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(15,4)
letuin1_nonreplied.plot(kind="bar", legend=True, ax=ax1, title="렛유인1_못푼개수", cmap="rainbow")
letuin1_total.plot(kind="bar", legend=True, ax=ax2, title="렛유인1_못푼개수+틀린개수", cmap="rainbow")
for p in ax1.patches:
    ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for q in ax2.patches :
    ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
plt.show()


# figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
# figure.set_size_inches(15,4)
# letuin2_nonreplied.plot(kind="bar", legend=False, ax=ax1, title="렛유인2_못푼개수", cmap="rainbow")
# letuin2_total.plot(kind="bar", legend=True, ax=ax2, title="렛유인2_못푼개수+틀린개수", cmap="rainbow")
# for p in ax1.patches:
#     ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
# for q in ax2.patches :
#     ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
# plt.show()


# figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
# figure.set_size_inches(15,4)
# letuin3_nonreplied.plot(kind="bar", legend=True, ax=ax1, title="렛유인3_못푼개수", cmap="rainbow")
# letuin3_total.plot(kind="bar", legend=True, ax=ax2, title="렛유인3_못푼개수+틀린개수", cmap="rainbow")
# for p in ax1.patches:
#     ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
# for q in ax2.patches :
#     ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
# plt.show()

# %% [markdown]
# ### 영역별 (못푼 개수) & (못푼+틀린 개수) [For comparison]

# %%
figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(15,4)
letuin1_nonreplied.T.plot(kind="bar", legend=True, ax=ax1, title="렛유인1_못푼개수", cmap="Paired")
letuin1_total.T.plot(kind="bar", legend=True, ax=ax2, title="렛유인1_못푼개수+틀린개수", cmap="Paired")
for p in ax1.patches:
    ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for q in ax2.patches :
    ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
plt.show()


# figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
# figure.set_size_inches(15,4)
# letuin2_nonreplied.T.plot(kind="bar", legend=False, ax=ax1, title="렛유인2_못푼개수", cmap="Paired")
# letuin2_total.T.plot(kind="bar", legend=True, ax=ax2, title="렛유인2_못푼개수+틀린개수", cmap="Paired")
# for p in ax1.patches:
#     ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
# for q in ax2.patches :
#     ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
# plt.show()


# figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
# figure.set_size_inches(15,4)
# letuin3_nonreplied.T.plot(kind="bar", legend=True, ax=ax1, title="렛유인3_못푼개수", cmap="Paired")
# letuin3_total.T.plot(kind="bar", legend=True, ax=ax2, title="렛유인3_못푼개수+틀린개수", cmap="Paired")
# for p in ax1.patches:
#     ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
# for q in ax2.patches :
#     ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
# plt.show()
