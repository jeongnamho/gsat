# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc("font", family = "Malgun Gothic")

# 글씨가 뭉게져서 보이는 것 같으면 아래의 설정을 통해서 개선할 수 있음
from IPython.display import display
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
# 여기는 건드리지 말 것!

df = pd.read_excel('score1.xlsx', index_col=None, header=[0,1])
df["언어오답률"] = df["언어", "못품"]/df["언어", "못품+틀림"]
df["수리오답률"] = df["수리","못품"]/df["수리", "못품+틀림"]
df["추리오답률"] = df["추리","못품"]/df["추리", "못품+틀림"]
df["시각오답률"] = df["시각","못품"]/df["시각", "못품+틀림"]
# df

df.style.set_properties(subset=[("언어", "못품+틀림"), ("수리", "못품+틀림"), ("추리", "못품+틀림"), ("시각", "못품+틀림")], 
                        **{'background-color':"lightgreen"})\
        .set_properties(subset=[("언어", "못품"), ("수리", "못품"), ("추리", "못품"), ("시각", "못품")], 
                       **{'background-color':"pink"})
# Out:
# <style  type="text/css" >
#     #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row0_col3 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row0_col4 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row0_col5 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row0_col6 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row0_col7 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row0_col8 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row0_col9 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row0_col10 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row1_col3 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row1_col4 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row1_col5 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row1_col6 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row1_col7 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row1_col8 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row1_col9 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row1_col10 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row2_col3 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row2_col4 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row2_col5 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row2_col6 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row2_col7 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row2_col8 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row2_col9 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row2_col10 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row3_col3 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row3_col4 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row3_col5 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row3_col6 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row3_col7 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row3_col8 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row3_col9 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row3_col10 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row4_col3 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row4_col4 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row4_col5 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row4_col6 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row4_col7 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row4_col8 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row4_col9 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row4_col10 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row5_col3 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row5_col4 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row5_col5 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row5_col6 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row5_col7 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row5_col8 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row5_col9 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row5_col10 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row6_col3 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row6_col4 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row6_col5 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row6_col6 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row6_col7 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row6_col8 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row6_col9 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row6_col10 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row7_col3 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row7_col4 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row7_col5 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row7_col6 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row7_col7 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row7_col8 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row7_col9 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row7_col10 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row8_col3 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row8_col4 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row8_col5 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row8_col6 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row8_col7 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row8_col8 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row8_col9 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row8_col10 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row9_col3 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row9_col4 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row9_col5 {
#             background-color:  pink;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row9_col6 {
#             background-color:  lightgreen;
#         }    #T_7f3921c0_8af0_11ea_9395_b808cfcc3516row9_col7 {

# %% [markdown]
# ---

# %% [markdown]
# # <font color=red> Weport_Final </font>

# %%
df = pd.read_excel('score1.xlsx', index_col=[0], header=[0,1])

weport1 = df.loc[(df["Unnamed: 1_level_0", "교재"] == "위포트_파이널") & (df["Unnamed: 2_level_0", "회차"] ==1)]
weport1.style.background_gradient(cmap='summer_r')
# print(weport1)
# print(weport1)

weport2 = df.loc[(df["Unnamed: 1_level_0", "교재"] == "위포트_파이널") & (df["Unnamed: 2_level_0", "회차"] ==2)]
weport2.style.background_gradient(cmap='summer_r')

# weport3 = df.loc[(df["Unnamed: 1_level_0", "교재"] == "위포트_파이널") & (df["Unnamed: 2_level_0", "회차"] ==3)]
# weport3.style.background_gradient(cmap='summer_r')

display(weport1.style.background_gradient(cmap='summer_r'))
display(weport2.style.background_gradient(cmap='summer_r'))
# display(weport3.style.background_gradient(cmap='summer_r'))
# 각 과목당 오답률
# df.iloc[:,9:]
# Out:
# <style  type="text/css" >
#     #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row0_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row0_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row0_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row0_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row0_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row1_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row1_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row1_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row1_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row1_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row2_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row2_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row2_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row2_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row2_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row2_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row2_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row2_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row2_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row3_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row3_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row3_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row3_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row3_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row3_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row3_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row3_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row4_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row4_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row4_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row4_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row4_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row4_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row4_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row4_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row4_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row5_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row5_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row5_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row5_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row5_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row5_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row5_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8849f54c_8af0_11ea_94e9_b808cfcc3516row5_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_8849f54c_8af0_11ea_94e9_b808cfcc3516" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Unnamed: 1_level_0</th>        <th class="col_heading level0 col1" >Unnamed: 2_level_0</th>        <th class="col_heading level0 col2" colspan=2>언어</th>        <th class="col_heading level0 col4" colspan=2>수리</th>        <th class="col_heading level0 col6" colspan=2>추리</th>        <th class="col_heading level0 col8" colspan=2>시각</th>    </tr>    <tr>        <th class="index_name level1" >이름</th>        <th class="col_heading level1 col0" >교재</th>        <th class="col_heading level1 col1" >회차</th>        <th class="col_heading level1 col2" >못품</th>        <th class="col_heading level1 col3" >못품+틀림</th>        <th class="col_h
# <style  type="text/css" >
#     #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row0_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row0_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row0_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row0_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row0_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row1_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row1_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row1_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row1_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row1_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row2_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row2_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row2_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row2_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row2_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row2_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row2_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row2_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row2_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row3_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row3_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row3_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row3_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row3_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row3_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row3_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row3_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row4_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row4_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row4_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row4_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row4_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row4_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row4_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row4_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row4_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row5_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row5_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row5_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row5_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row5_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row5_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row5_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_885fcde2_8af0_11ea_a9b7_b808cfcc3516row5_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_885fcde2_8af0_11ea_a9b7_b808cfcc3516" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Unnamed: 1_level_0</th>        <th class="col_heading level0 col1" >Unnamed: 2_level_0</th>        <th class="col_heading level0 col2" colspan=2>언어</th>        <th class="col_heading level0 col4" colspan=2>수리</th>        <th class="col_heading level0 col6" colspan=2>추리</th>        <th class="col_heading level0 col8" colspan=2>시각</th>    </tr>    <tr>        <th class="index_name level1" >이름</th>        <th class="col_heading level1 col0" >교재</th>        <th class="col_heading level1 col1" >회차</th>        <th class="col_heading level1 col2" >못품</th>        <th class="col_heading level1 col3" >못품+틀림</th>        <th class="col_h

# %%
weport1_nonreplied = weport1.iloc[:,[2,4,6,8]]
weport1_total = weport1.iloc[:,[3,5,7,9]]
weport2_nonreplied = weport2.iloc[:,[2,4,6,8]]
weport2_total = weport2.iloc[:,[3,5,7,9]]
# weport3_nonreplied = weport3.iloc[:,[2,4,6,8]]
# weport3_total = weport3.iloc[:,[3,5,7,9]]

# %% [markdown]
# ### 개인별  (못푼 개수) & (못푼+틀린 개수)

# %%
figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(15,4)
weport1_nonreplied.plot(kind="bar", legend=True, ax=ax1, title="위포트1_못푼개수", cmap="rainbow")
weport1_total.plot(kind="bar", legend=True, ax=ax2, title="위포트1_못푼개수+틀린개수", cmap="rainbow")
for p in ax1.patches:
    ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for q in ax2.patches :
    ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
plt.show()


figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(15,4)
weport2_nonreplied.plot(kind="bar", legend=False, ax=ax1, title="위포트2_못푼개수", cmap="rainbow")
weport2_total.plot(kind="bar", legend=True, ax=ax2, title="위포트2_못푼개수+틀린개수", cmap="rainbow")
for p in ax1.patches:
    ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for q in ax2.patches :
    ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
plt.show()


# figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
# figure.set_size_inches(15,4)
# weport3_nonreplied.plot(kind="bar", legend=True, ax=ax1, title="위포트3_못푼개수", cmap="rainbow")
# weport3_total.plot(kind="bar", legend=True, ax=ax2, title="위포트3_못푼개수+틀린개수", cmap="rainbow")
# for p in ax1.patches:
#     ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
# for q in ax2.patches :
#     ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
# plt.show()

# %% [markdown]
# ### 영역별 (못푼 개수) & (못푼+틀린 개수) [For comparison]

# %%
figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(15,4)
weport1_nonreplied.T.plot(kind="bar", legend=True, ax=ax1, title="위포트1_못푼개수", cmap="Paired")
weport1_total.T.plot(kind="bar", legend=True, ax=ax2, title="위포트1_못푼개수+틀린개수", cmap="Paired")
for p in ax1.patches:
    ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for q in ax2.patches :
    ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
plt.show()


figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(15,4)
weport2_nonreplied.T.plot(kind="bar", legend=False, ax=ax1, title="위포트2_못푼개수", cmap="Paired")
weport2_total.T.plot(kind="bar", legend=True, ax=ax2, title="위포트2_못푼개수+틀린개수", cmap="Paired")
for p in ax1.patches:
    ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for q in ax2.patches :
    ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
plt.show()


# figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
# figure.set_size_inches(15,4)
# weport3_nonreplied.T.plot(kind="bar", legend=True, ax=ax1, title="위포트3_못푼개수", cmap="Paired")
# weport3_total.T.plot(kind="bar", legend=True, ax=ax2, title="위포트3_못푼개수+틀린개수", cmap="Paired")
# for p in ax1.patches:
#     ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
# for q in ax2.patches :
#     ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
# plt.show()
