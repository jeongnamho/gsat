# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc("font", family = "Malgun Gothic")

# 글씨가 뭉게져서 보이는 것 같으면 아래의 설정을 통해서 개선할 수 있음
from IPython.display import display
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
# 여기는 건드리지 말 것!

df = pd.read_excel('score.xlsx', index_col=None, header=[0,1])
df["언어오답률"] = df["언어", "못품"]/df["언어", "못품+틀림"]
df["수리오답률"] = df["수리","못품"]/df["수리", "못품+틀림"]
df["추리오답률"] = df["추리","못품"]/df["추리", "못품+틀림"]
df["시각오답률"] = df["시각","못품"]/df["시각", "못품+틀림"]
# df

df.style.set_properties(subset=[("언어", "못품+틀림"), ("수리", "못품+틀림"), ("추리", "못품+틀림"), ("시각", "못품+틀림")], 
                        **{'background-color':"lightgreen"})\
        .set_properties(subset=[("언어", "못품"), ("수리", "못품"), ("추리", "못품"), ("시각", "못품")], 
                       **{'background-color':"pink"})
# Out:
# <style  type="text/css" >
#     #T_83957c76_6ea8_11ea_9058_b808cfcc3516row0_col3 {
#             background-color:  pink;
#         }    #T_83957c76_6ea8_11ea_9058_b808cfcc3516row0_col4 {
#             background-color:  lightgreen;
#         }    #T_83957c76_6ea8_11ea_9058_b808cfcc3516row0_col5 {
#             background-color:  pink;
#         }    #T_83957c76_6ea8_11ea_9058_b808cfcc3516row0_col6 {
#             background-color:  lightgreen;
#         }    #T_83957c76_6ea8_11ea_9058_b808cfcc3516row0_col7 {
#             background-color:  pink;
#         }    #T_83957c76_6ea8_11ea_9058_b808cfcc3516row0_col8 {
#             background-color:  lightgreen;
#         }    #T_83957c76_6ea8_11ea_9058_b808cfcc3516row0_col9 {
#             background-color:  pink;
#         }    #T_83957c76_6ea8_11ea_9058_b808cfcc3516row0_col10 {
#             background-color:  lightgreen;
#         }    #T_83957c76_6ea8_11ea_9058_b808cfcc3516row1_col3 {
#             background-color:  pink;
# ...

# %% [markdown]
# # <font color=red> Letuin </font>

# %%
df = pd.read_excel('score.xlsx', index_col=[0], header=[0,1])

letuin1 = df.loc[(df["Unnamed: 1_level_0", "교재"] == "렛유인실전") & (df["Unnamed: 2_level_0", "회차"] ==1)]
letuin1.style.background_gradient(cmap='summer_r')
# print(letuin1)
# print(letuin1)

letuin2 = df.loc[(df["Unnamed: 1_level_0", "교재"] == "렛유인실전") & (df["Unnamed: 2_level_0", "회차"] ==2)]
letuin2.style.background_gradient(cmap='summer_r')

letuin3 = df.loc[(df["Unnamed: 1_level_0", "교재"] == "렛유인실전") & (df["Unnamed: 2_level_0", "회차"] ==3)]
letuin3.style.background_gradient(cmap='summer_r')

letuin4 = df.loc[(df["Unnamed: 1_level_0", "교재"] == "렛유인실전") & (df["Unnamed: 2_level_0", "회차"] ==4)]
letuin4.style.background_gradient(cmap='summer_r')

display(letuin1.style.background_gradient(cmap='summer_r'))
display(letuin2.style.background_gradient(cmap='summer_r'))
display(letuin3.style.background_gradient(cmap='summer_r'))
display(letuin4.style.background_gradient(cmap='summer_r'))
# 각 과목당 오답률
# df.iloc[:,9:]
# Out:
# C:\Users\jnh78\AppData\Roaming\Python\Python37\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_bced202c_6ea8_11ea_886e_b808cfcc3516row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_bced202c_6ea8_11ea_886e_b808cfcc3516row0_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_bced202c_6ea8_11ea_886e_b808cfcc3516row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_bced202c_6ea8_11ea_886e_b808cfcc3516row0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_bced202c_6ea8_11ea_886e_b808cfcc3516row0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_bced202c_6ea8_11ea_886e_b808cfcc3516row0_col6 {
#             background-color:  #ffff66;
# ...

# %%
letuin1_nonreplied = letuin1.iloc[:,[2,4,6,8]]
letuin1_total = letuin1.iloc[:,[3,5,7,9]]
letuin2_nonreplied = letuin2.iloc[:,[2,4,6,8]]
letuin2_total = letuin2.iloc[:,[3,5,7,9]]
letuin3_nonreplied = letuin3.iloc[:,[2,4,6,8]]
letuin3_total = letuin3.iloc[:,[3,5,7,9]]
letuin4_nonreplied = letuin4.iloc[:,[2,4,6,8]]
letuin4_total = letuin4.iloc[:,[3,5,7,9]]

# %% [markdown]
# ### 개인별  (못푼 개수) & (못푼+틀린 개수)

# %%
figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(15,4)
letuin1_nonreplied.plot(kind="bar", legend=True, ax=ax1, title="렛유인1_못푼개수", cmap="rainbow")
letuin1_total.plot(kind="bar", legend=True, ax=ax2, title="렛유인1_못푼개수+틀린개수", cmap="rainbow")
for p in ax1.patches:
    ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for q in ax2.patches :
    ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
plt.show()


figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(15,4)
letuin2_nonreplied.plot(kind="bar", legend=False, ax=ax1, title="렛유인2_못푼개수", cmap="rainbow")
letuin2_total.plot(kind="bar", legend=True, ax=ax2, title="렛유인2_못푼개수+틀린개수", cmap="rainbow")
for p in ax1.patches:
    ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for q in ax2.patches :
    ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
plt.show()


figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(15,4)
letuin3_nonreplied.plot(kind="bar", legend=True, ax=ax1, title="렛유인3_못푼개수", cmap="rainbow")
letuin3_total.plot(kind="bar", legend=True, ax=ax2, title="렛유인3_못푼개수+틀린개수", cmap="rainbow")
for p in ax1.patches:
    ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for q in ax2.patches :
    ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
plt.show()

figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(15,4)
letuin4_nonreplied.plot(kind="bar", legend=True, ax=ax1, title="렛유인4_못푼개수", cmap="rainbow")
letuin4_total.plot(kind="bar", legend=True, ax=ax2, title="렛유인4_못푼개수+틀린개수", cmap="rainbow")
for p in ax1.patches:
    ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for q in ax2.patches :
    ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
plt.show()

# %% [markdown]
# ### 영역별 (못푼 개수) & (못푼+틀린 개수) [For comparison]

# %%
figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(15,4)
letuin1_nonreplied.T.plot(kind="bar", legend=True, ax=ax1, title="렛유인1_못푼개수", cmap="Paired")
letuin1_total.T.plot(kind="bar", legend=True, ax=ax2, title="렛유인1_못푼개수+틀린개수", cmap="Paired")
for p in ax1.patches:
    ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for q in ax2.patches :
    ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
plt.show()


figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(15,4)
letuin2_nonreplied.T.plot(kind="bar", legend=False, ax=ax1, title="렛유인2_못푼개수", cmap="Paired")
letuin2_total.T.plot(kind="bar", legend=True, ax=ax2, title="렛유인2_못푼개수+틀린개수", cmap="Paired")
for p in ax1.patches:
    ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for q in ax2.patches :
    ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
plt.show()


figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(15,4)
letuin3_nonreplied.T.plot(kind="bar", legend=True, ax=ax1, title="렛유인3_못푼개수", cmap="Paired")
letuin3_total.T.plot(kind="bar", legend=True, ax=ax2, title="렛유인3_못푼개수+틀린개수", cmap="Paired")
for p in ax1.patches:
    ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for q in ax2.patches :
    ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
plt.show()

figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(15,4)
letuin4_nonreplied.T.plot(kind="bar", legend=True, ax=ax1, title="렛유인4_못푼개수", cmap="Paired")
letuin4_total.T.plot(kind="bar", legend=True, ax=ax2, title="렛유인4_못푼개수+틀린개수", cmap="Paired")
for p in ax1.patches:
    ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for q in ax2.patches :
    ax2.annotate(str(q.get_height()), (q.get_x() * 1.005, q.get_height() * 1.005))
plt.show()
